# %% [markdown]
# <a href="https://colab.research.google.com/github/jilla-28/jilla-portfolio/blob/main/DRL_Inventory_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

DataCo = 'DataCoSupplyChainDataset.csv'

Data = pd.read_csv(DataCo, encoding='latin1')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
Data.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                 0.0         73.0  Sporting Goods        Caguas  ...
# 1                 1.0         73.0  Sporting Goods        Caguas  ...
# 2                 0.0         73.0  Sporting Goods      San Jose  ...
# 3                 0.0         73.0  Sporting Goods   Los Angeles  ...
# 4                 0.0         73.0  Sporting Goods        Caguas  ...
#
#   Order Zipcode Product Card Id Product Category Id  Product Description  \
# 0           NaN          1360.0                73.0                  NaN
# 1           NaN          1360.0                73.0                  NaN
# 2           NaN          1360.0                73.0                  NaN
# 3           NaN          1360.0                73.0                  NaN
# 4           NaN          1360.0                73.0                  NaN
#
#                                   Product Image  Product Name Product Price  \
# 0  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 1  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 2  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 3  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 4  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
#
#   Product Status shipping date (DateOrders)   Shipping Mode
# 0            0.0             2/3/2018 22:56  Standard Class
# 1            0.0            1/18/2018 12:27  Standard Class
# 2            0.0            1/17/2018 12:06  Standard Class
# 3            0.0            1/16/2018 11:45  Standard Class
# 4            0.0            1/15/2018 11:24  Standard Class
#
# [5 rows x 53 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75577 entries, 0 to 75576
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Type                           75577 non-null  object
#  1   Days for shipping (real)       75577 non-null  int64
#  2   Days for shipment (scheduled)  75577 non-null  int64
#  3   Benefit per order              75577 non-null  float64
#  4   Sales per customer             75577 non-null  float64
#  5   Delivery Status                75577 non-null  object
#  6   Late_delivery_risk             75576 non-null  float64
#  7   Category Id                    75576 non-null  float64
#  8   Category Name                  75576 non-null  object
#  9   Customer City                  75576 non-null  object
#  10  Customer Country               75576 non-null  object
#  11  Customer Email                 75576 non-null  object
#  12  Customer Fname                 75576 non-null  object
#  13  Customer Id                    75576 non-null  float64
#  14  Customer Lname                 75574 non-null  object
#  15  Customer Password              75576 non-null  object
#  16  Customer Segment               75576 non-null  object
#  17  Customer State                 75576 non-null  object
#  18  Customer Street                75576 non-null  object
#  19  Customer Zipcode               75574 non-null  float64
#  20  Department Id                  75576 non-null  float64
#  21  Department Name                75576 non-null  object
#  22  Latitude                       75576 non-null  float64
#  23  Longitude                      75576 non-null  float64
#  24  Market                         75576 non-null  object
#  25  Order City                     75576 non-null  object
#  26  Order Country                  75576 non-null  object
#  27  Order Customer Id              75576 non-null  float64
#  28  order date (DateOrders)        75576 non-null  object
#  29  Order Id                       75576 non-null  float64
#  30  Order Item Cardprod Id         75576 non-null  float64
#  31  Order Item Discount            75576 non-null  float64
#  32  Order Item Discount Rate       75576 non-null  float64
#  33  Order Item Id                  75576 non-null  float64
#  34  Order Item Product Price       75576 non-null  float64
#  35  Order Item Profit Ratio        75576 non-null  float64
#  36  Order Item Quantity            75576 non-null  float64
#  37  Sales                          75576 non-null  float64
#  38  Order Item Total               75576 non-null  float64
#  39  Order Profit Per Order         75576 non-null  float64
#  40  Order Region                   75576 non-null  object
#  41  Order State                    75576 non-null  object
#  42  Order Status                   75576 non-null  object
#  43  Order Zipcode                  9243 non-null   float64
#  44  Product Card Id                75576 non-null  float64
#  45  Product Category Id            75576 non-null  float64
#  46  Product Description            0 non-null      float64
#  47  Product Image                  75576 non-null  object
#  48  Product Name                   75576 non-null  object
#  49  Product Price                  75576 non-null  float64
#  50  Product Status                 75576 non-null  float64
#  51  shipping date (DateOrders)     75576 non-null  object
#  52  Shipping Mode                  75576 non-null  object
# dtypes: float64(27), int64(2), object(24)
# memory usage: 30.6+ MB

# %% [markdown]
# # Cleaning

# %%
# drop irrelevant columns to analysis like product description
Data.drop(columns=['Product Description'], inplace=True)

# %%
# imput unknown where values are missing in customer name column
Data['Customer Lname'].fillna('Unknown', inplace=True)
# Out:
# <ipython-input-6-543ab18141aa>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Data['Customer Lname'].fillna('Unknown', inplace=True)

# %%
# imput 00000 where customer zipcode is missing
Data['Customer Zipcode'].fillna(Data['Customer Zipcode'].mode()[0], inplace=True)
# Out:
# <ipython-input-7-ebc9cb9dfb2d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Data['Customer Zipcode'].fillna(Data['Customer Zipcode'].mode()[0], inplace=True)

# %%
# imput 00000 where order zipcode is missing
Data['Order Zipcode'].fillna(Data['Order Zipcode'].mode()[0], inplace=True)
# Out:
# <ipython-input-8-023043bf7760>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Data['Order Zipcode'].fillna(Data['Order Zipcode'].mode()[0], inplace=True)

# %%
# check for remaining nulls
print(Data.isnull().sum())
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               1
# Category Id                      1
# Category Name                    1
# Customer City                    1
# Customer Country                 1
# Customer Email                   1
# Customer Fname                   1
# Customer Id                      1
# Customer Lname                   0
# Customer Password                1
# Customer Segment                 1
# Customer State                   1
# Customer Street                  1
# Customer Zipcode                 0
# Department Id                    1
# Department Name                  1
# Latitude                         1
# Longitude                        1
# Market                           1
# Order City                       1
# Order Country                    1
# Order Customer Id                1
# order date (DateOrders)          1
# Order Id                         1
# Order Item Cardprod Id           1
# Order Item Discount              1
# Order Item Discount Rate         1
# Order Item Id                    1
# Order Item Product Price         1
# Order Item Profit Ratio          1
# Order Item Quantity              1
# Sales                            1
# Order Item Total                 1
# Order Profit Per Order           1
# Order Region                     1
# Order State                      1
# Order Status                     1
# Order Zipcode                    0
# Product Card Id                  1
# Product Category Id              1
# Product Image                    1
# Product Name                     1
# Product Price                    1
# Product Status                   1
# shipping date (DateOrders)       1
# Shipping Mode                    1
# dtype: int64

# %%
# check for duplicates
Data.drop_duplicates(inplace=True)

# %%
Data.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count              75577.000000                   75577.000000
# mean                   3.412070                       2.763089
# std                    1.631793                       1.404464
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count       75577.000000        75577.000000        75576.000000
# mean           21.578016          176.578668            0.585715
# std           102.353846          118.782961            0.492601
# min         -4274.979980            7.490000            0.000000
# 25%             6.520000          103.989998            0.000000
# 50%            30.809999          161.089996            1.000000
# 75%            63.000000          237.559998            1.000000
# max           864.000000         1899.989990            1.000000
#
#         Category Id   Customer Id  Customer Zipcode  Department Id  \
# count  75576.000000  75576.000000      75577.000000   75576.000000
# mean      29.311898   6780.534178      37811.730871       5.134196
# std       15.858035   4295.148389      37642.766795       1.610924
# min        2.000000      1.000000        603.000000       2.000000
# 25%       17.000000   3249.750000        725.000000       4.000000
# 50%       24.000000   6516.000000      23452.000000       5.000000
# 75%       43.000000   9885.000000      78840.000000       7.000000
# max       76.000000  20757.000000      99205.000000      12.000000
#
#            Latitude  ...  Order Item Profit Ratio  Order Item Quantity  \
# count  75576.000000  ...             75576.000000         75576.000000
# mean      30.304326  ...                 0.123267             2.184794
# std        9.673446  ...                 0.463431             1.504331
# min      -33.937553  ...                -2.750000             1.000000
# 25%       18.272686  ...                 0.080000             1.000000
# 50%       33.671467  ...                 0.270000             1.000000
# 75%       39.495914  ...                 0.360000             3.000000
# max       48.781933  ...                 0.500000             5.000000
#
#               Sales  Order Item Total  Order Profit Per Order  Order Zipcode  \
# count  75576.000000      75576.000000            75576.000000   75577.000000
# mean     196.629775        176.578596               21.577170   15601.068116
# std      131.349371        118.783745              102.354259   18628.823686
# min        9.990000          7.490000            -4274.979980    1453.000000
# 25%      119.980003        103.989998                6.520000   10035.000000
# 50%      191.960007        161.089996               30.809999   10035.000000
# 75%      250.000000        237.559998               63.000000   10035.000000
# max     1999.989990       1899.989990              864.000000   99301.000000
#
#        Product Card Id  Product Category Id  Product Price  Product Status
# count     75576.000000         75576.000000   75576.000000         75576.0
# mean        632.991426            29.311898     130.354764             0.0
# std         334.946239            15.858035     130.472877             0.0
# min          19.000000             2.000000       9.990000             0.0
# 25%         365.000000            17.000000      50.000000             0.0
# 50%         502.000000            24.000000      99.989998             0.0
# 75%         957.000000            43.000000     199.990005             0.0
# max        1363.000000            76.000000    1999.989990             0.0
#
# [8 rows x 28 columns]

# %% [markdown]
# Checking for outliers

# %%
import numpy as np

# Select only the numeric columns in the dataframe
numeric_cols = Data.select_dtypes(include=[np.number]).columns

# For each numeric column, calculate mean and standard deviation
for col in numeric_cols:
    mean = Data[col].mean()
    std = Data[col].std()

    # Define the upper and lower bounds for outliers (3 standard deviations from the mean)
    upper_bound = mean + 3 * std
    lower_bound = mean - 3 * std

    # Filter out rows where the values in the column are outliers
    Data = Data[(Data[col] <= upper_bound) & (Data[col] >= lower_bound)]

# Print the cleaned dataset without outliers
print(Data)
# Out:
#            Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 48      PAYMENT                         5                              2
# 50      PAYMENT                         6                              2
# 51      PAYMENT                         2                              2
# 52      PAYMENT                         3                              2
# 53      PAYMENT                         5                              2
# ...         ...                       ...                            ...
# 75570  TRANSFER                         2                              4
# 75571  TRANSFER                         4                              4
# 75572  TRANSFER                         2                              2
# 75573      CASH                         4                              2
# 75575     DEBIT                         0                              0
#
#        Benefit per order  Sales per customer    Delivery Status  \
# 48            -30.750000          115.180000      Late delivery
# 50             33.599998           96.000000      Late delivery
# 51             24.690001           75.980003   Shipping on time
# 52              9.100000           91.000000      Late delivery
# 53            -21.750000           87.000000      Late delivery
# ...                  ...                 ...                ...
# 75570          70.559998          195.990005   Advance shipping
# 75571          67.900002          193.990005   Shipping on time
# 75572          46.080002          191.990005  Shipping canceled
# 75573          21.469999          189.990005      Late delivery
# 75575          60.450001          185.990005   Shipping on time
#
#        Late_delivery_risk  Category Id    Category Name Customer City  ...  \
# 48                    1.0         17.0           Cleats       Bayamon  ...
# 50                    1.0         24.0  Women's Apparel        Caguas  ...
# 51                    0.0         29.0    Shop By Sport        Caguas  ...
# 52                    1.0         24.0  Women's Apparel        Caguas  ...
# 53                    1.0         24.0  Women's Apparel        Caguas  ...
# ...                   ...          ...              ...           ...  ...
# 75570                 0.0         48.0     Water Sports    Washington  ...
# 75571                 0.0         48.0     Water Sports  Philadelphia  ...
# 75572                 0.0         48.0     Water Sports        Ithaca  ...
# 75573                 1.0         48.0     Water Sports        Caguas  ...
# 75575                 0.0         48.0     Water Sports        Caguas  ...
#
#           Order Status Order Zipcode Product Card Id  Product Category Id  \
# 48     PENDING_PAYMENT       10035.0           365.0                 17.0
# 50     PENDING_PAYMENT       10035.0           502.0                 24.0
# 51     PENDING_PAYMENT       10035.0           627.0                 29.0
# 52     PENDING_PAYMENT       10035.0           502.0                 24.0
# 53     PENDING_PAYMENT       10035.0           502.0                 24.0
# ...                ...           ...             ...                  ...
# 75570       PROCESSING       10035.0          1073.0                 48.0
# 75571       PROCESSING       10035.0          1073.0                 48.0
# 75572  SUSPECTED_FRAUD       10035.0          1073.0                 48.0
# 75573           CLOSED       10035.0          1073.0                 48.0
# 75575         COMPLETE       10035.0          1073.0                 48.0
#
#                                            Product Image  \
# 48     http://images.acmesports.sports/Perfect+Fitnes...
# 50     http://images.acmesports.sports/Nike+Men%27s+D...
# 51     http://images.acmesports.sports/Under+Armour+G...
# 52     http://images.acmesports.sports/Nike+Men%27s+D...
# 53     http://images.acmesports.sports/Nike+Men%27s+D...
# ...                                                  ...
# 75570  http://images.acmesports.sports/Pelican+Sunstr...
# 75571  http://images.acmesports.sports/Pelican+Sunstr...
# 75572  http://images.acmesports.sports/Pelican+Sunstr...
# 75573  http://images.acmesports.sports/Pelican+Sunstr...
# 75575  http://images.acmesports.sports/Pelican+Sunstr...
#
#                                         Product Name Product Price  \
# 48                  Perfect Fitness Perfect Rip Deck     59.990002
# 50              Nike Men's Dri-FIT Victory Golf Polo     50.000000
# 51     Under Armour Girls' Toddler Spine Surge Runni     39.990002
# 52              Nike Men's Dri-FIT Victory Golf Polo     50.000000
# 53              Nike Men's Dri-FIT Victory Golf Polo     50.000000
# ...                                              ...           ...
# 75570                    Pelican Sunstream 100 Kayak    199.990005
# 75571                    Pelican Sunstream 100 Kayak    199.990005
# 75572                    Pelican Sunstream 100 Kayak    199.990005
# 75573                    Pelican Sunstream 100 Kayak    199.990005
# 75575                    Pelican Sunstream 100 Kayak    199.990005
#
#       Product Status shipping date (DateOrders)   Shipping Mode
# 48               0.0            2/29/2016 13:57    Second Class
# 50               0.0              4/5/2016 4:37    Second Class
# 51               0.0             11/1/2016 1:31    Second Class
# 52               0.0             12/1/2016 1:18    Second Class
# 53               0.0             1/5/2017 15:47    Second Class
# ...              ...                        ...             ...
# 75570            0.0             4/6/2015 17:12  Standard Class
# 75571            0.0             4/8/2015 16:09  Standard Class
# 75572            0.0             4/6/2015 15:27    Second Class
# 75573            0.0             4/8/2015 12:39    Second Class
# 75575            0.0             4/4/2015 22:33        Same Day
#
# [62219 rows x 52 columns]

# %% [markdown]
# The outliers are now removed from the data.

# %%
# dealing with dtypes
#Convert date columns to datetime
Data['order date (DateOrders)'] = pd.to_datetime(Data['order date (DateOrders)'], errors='coerce')
Data['shipping date (DateOrders)'] = pd.to_datetime(Data['shipping date (DateOrders)'], errors='coerce')

# %%
# Convert Zipcode into string object
Data['Customer Zipcode'] = Data['Customer Zipcode'].astype(str)
Data['Order Zipcode'] = Data['Order Zipcode'].astype(str)

# %%
Data.dtypes
# Out:
# Type                                     object
# Days for shipping (real)                  int64
# Days for shipment (scheduled)             int64
# Benefit per order                       float64
# Sales per customer                      float64
# Delivery Status                          object
# Late_delivery_risk                      float64
# Category Id                             float64
# Category Name                            object
# Customer City                            object
# Customer Country                         object
# Customer Email                           object
# Customer Fname                           object
# Customer Id                             float64
# Customer Lname                           object
# Customer Password                        object
# Customer Segment                         object
# Customer State                           object
# Customer Street                          object
# Customer Zipcode                         object
# Department Id                           float64
# Department Name                          object
# Latitude                                float64
# Longitude                               float64
# Market                                   object
# Order City                               object
# Order Country                            object
# Order Customer Id                       float64
# order date (DateOrders)          datetime64[ns]
# Order Id                                float64
# Order Item Cardprod Id                  float64
# Order Item Discount                     float64
# Order Item Discount Rate                float64
# Order Item Id                           float64
# Order Item Product Price                float64
# Order Item Profit Ratio                 float64
# Order Item Quantity                     float64
# Sales                                   float64
# Order Item Total                        float64
# Order Profit Per Order                  float64
# Order Region                             object
# Order State                              object
# Order Status                             object
# Order Zipcode                            object
# Product Card Id                         float64
# Product Category Id                     float64
# Product Image                            object
# Product Name                             object
# Product Price                           float64
# Product Status                          float64
# shipping date (DateOrders)       datetime64[ns]
# Shipping Mode                            object
# dtype: object

# %%
Data.to_csv('cleaned_dataset.csv', index=False)

# %%
print(Data.describe())
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count              62219.000000                   62219.000000
# mean                   3.406435                       2.759495
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
# std                    1.634092                       1.406699
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count       62219.000000        62219.000000        62219.000000
# mean           35.505342          162.930807            0.584773
# min          -136.779999            7.490000            0.000000
# 25%            10.300000          103.989998            0.000000
# 50%            32.880001          150.000000            1.000000
# 75%            62.400002          212.500000            1.000000
# max           197.990005          425.200012            1.000000
# std            48.017188           86.671364            0.492765
#
#         Category Id   Customer Id  Department Id      Latitude     Longitude  \
# count  62219.000000  62219.000000   62219.000000  62219.000000  62219.000000
# mean      27.772786   6305.986612       5.063389     30.341204    -85.570503
# min        2.000000      2.000000       2.000000     17.982491   -125.450050
# 25%       17.000000   3129.000000       4.000000     18.271360   -100.499184
# 50%       24.000000   6239.000000       5.000000     33.701370    -78.741943
# 75%       43.000000   9448.000000       7.000000     39.495914    -66.370590
# max       70.000000  18031.000000       9.000000     48.781933    -65.825951
# std       13.313438   3712.781898       1.407230      9.669639     20.266168
#
#        ...  Order Item Profit Ratio Order Item Quantity         Sales  \
# count  ...             62219.000000        62219.000000  62219.000000
# mean   ...                 0.206764            2.164114    181.037567
# min    ...                -0.980000            1.000000      9.990000
# 25%    ...                 0.090000            1.000000    119.980003
# 50%    ...                 0.280000            1.000000    179.970001
# 75%    ...                 0.360000            3.000000    239.960007
# max    ...                 0.500000            5.000000    474.950012
# std    ...                 0.266121            1.467595     94.442154
#
#        Order Item Total  Order Profit Per Order  Product Card Id  \
# count      62219.000000            62219.000000      62219.00000
# mean         162.930807               35.505342        607.37090
# min            7.490000             -136.779999         19.00000
# 25%          103.989998               10.300000        365.00000
# 50%          150.000000               32.880001        502.00000
# 75%          212.500000               62.400002        957.00000
# max          425.200012              197.990005       1357.00000
# std           86.671364               48.017188        300.28297
#
#        Product Category Id  Product Price  Product Status  \
# count         62219.000000   62219.000000         62219.0
# mean             27.772786     120.167029             0.0
# min               2.000000       9.990000             0.0
# 25%              17.000000      50.000000             0.0
# 50%              24.000000      59.990002             0.0
# 75%              43.000000     199.990005             0.0
# max              70.000000     399.989990             0.0
# std              13.313438      98.206034             0.0
#
#           shipping date (DateOrders)
# count                          62219
# mean   2016-06-05 06:04:21.046626048
# min              2015-01-03 00:00:00
# 25%              2015-08-26 17:37:30
# 50%              2016-06-20 17:12:00
# 75%              2017-03-08 05:01:00
# max              2017-12-29 03:33:00
# std                              NaN
#
# [8 rows x 28 columns]

# %%
# visualize data to understand distribution
import matplotlib.pyplot as plt

# Create histogram to visualize the distribution
Data['Benefit per order'].hist(bins=50)
plt.title('Distribution of Benefit per order (Cleaned Data)')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 15))

# Create histogram to visualize the distribution of each column
Data.hist(bins=50, ax=ax)

# Adjust layout to prevent overlap and rotate x-axis labels
plt.tight_layout()
plt.xticks(rotation=45)

# Rotate the x-axis labels for better readability
plt.show()
# Out:
# <ipython-input-19-7cd42310e101>:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   Data.hist(bins=50, ax=ax)

# %% [markdown]
# **Data Cleaning and Feature Selection:**
#
# We cleaned the data by removing unnecessary columns, handling missing values, outliers, converting data types, and ensuring normalization. Selected relevant features for stockout prediction:'Days for shipping (real)', 'Late_delivery_risk', 'Sales per customer,' and 'Benefit per order. This

# %% [markdown]
# # Custom Gym Environment for Stockout Mitigation Using Reinforcement Learning

# %%
import gym
from gym import spaces
import numpy as np
from collections import defaultdict

class InventoryManagementEnv(gym.Env):
    def __init__(self, Data):
        super(InventoryManagementEnv, self).__init__()
        self.Data = Data
        self.current_step = 0
        self.inventory = 50
        self.max_inventory = 100
        self.restock_amounts = [0, 10, 20]
        self.shipping_cost = {'standard': 5, 'expedited': 15}
        self.stockout_penalty = -50
        self.holding_cost_rate = -1
        self.sale_profit = 20
        self.late_delivery_penalty = -25

        # Cumulative reward tracking
        self.cumulative_rewards = defaultdict(lambda: {'total_reward': 0, 'count': 0})

        # Define action and observation space
        self.action_space = spaces.MultiDiscrete([3, 2])  # Restock, Shipping Priority
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(6,), dtype=np.float32
        )

    def reset(self):
        self.current_step = 0
        self.inventory = 50
        self.cumulative_rewards = defaultdict(lambda: {'total_reward': 0, 'count': 0})  # Reset cumulative rewards
        return self._get_observation()

    def step(self, action):
        restock_action, shipping_action = action
        restock_amount = self.restock_amounts[restock_action]
        self.inventory = min(self.inventory + restock_amount, self.max_inventory)

        current_row = self.Data.iloc[self.current_step]
        demand = current_row['Sales per customer']
        late_risk = current_row['Late_delivery_risk']
        shipping_days_real = current_row['Days for shipping (real)']
        shipping_days_scheduled = current_row['Days for shipment (scheduled)']

        # Calculate individual reward components
        fulfilled_demand = min(self.inventory, demand)
        self.inventory -= fulfilled_demand

        revenue = fulfilled_demand * self.sale_profit
        holding_cost = self.inventory * self.holding_cost_rate
        stockout_cost = self.stockout_penalty if fulfilled_demand < demand else 0
        shipping_cost = self.shipping_cost['expedited'] if shipping_action == 1 else self.shipping_cost['standard']
        late_penalty = self.late_delivery_penalty * late_risk if shipping_days_real > shipping_days_scheduled else 0

        total_reward = revenue + holding_cost + stockout_cost - shipping_cost + late_penalty

        # Track cumulative rewards for each action
        action_type = f"Restock: {restock_action}, Shipping: {shipping_action}"
        self.cumulative_rewards[action_type]['total_reward'] += total_reward
        self.cumulative_rewards[action_type]['count'] += 1

        # Create a dictionary to store individual reward components
        reward_components = {
            'revenue': revenue,
            'holding_cost': holding_cost,
            'stockout_cost': stockout_cost,
            'shipping_cost': -shipping_cost,  # Negative because it's a cost
            'late_penalty': late_penalty
        }

        self.current_step += 1
        done = self.current_step >= len(self.Data)

        return self._get_observation(), total_reward, done, reward_components

    def _get_observation(self):
        if self.current_step < len(self.Data):
            current_row = self.Data.iloc[self.current_step]
            return np.array([
                self.inventory,
                current_row['Sales per customer'],
                current_row['Days for shipping (real)'],
                current_row['Days for shipment (scheduled)'],
                current_row['Late_delivery_risk'],
                current_row['Benefit per order']
            ], dtype=np.float32)
        else:
            return np.zeros(6, dtype=np.float32)

    def render(self, mode='human', verbosity=1):
        if verbosity == 0:
            print(f"Step: {self.current_step}, Inventory Level: {self.inventory}")
        elif verbosity == 1:
            if self.current_step < len(self.Data):
                current_row = self.Data.iloc[self.current_step]
                print(f"Step: {self.current_step}")
                print(f"Inventory Level: {self.inventory}")
                print(f"Sales per Customer: {current_row['Sales per customer']}")
                print(f"Days for Shipping (Real): {current_row['Days for shipping (real)']}")
                print(f"Days for Shipment (Scheduled): {current_row['Days for shipment (scheduled)']}")
                print(f"Late Delivery Risk: {current_row['Late_delivery_risk']}")
                print(f"Benefit per Order: {current_row['Benefit per order']}")
                print("-" * 30)
            else:
                print(f"Step: {self.current_step} is out of bounds for the DataFrame.")

    def get_average_rewards(self):
        """Calculate and return average rewards for each action type."""
        averages = {}
        for action_type, data in self.cumulative_rewards.items():
            averages[action_type] = data['total_reward'] / data['count'] if data['count'] > 0 else 0
        return averages

# %% [markdown]
# Now that your custom environment is functioning correctly, the next step is to develop and train a Deep Q-Network (DQN) agent to interact with it. Here's a structured approach to guide you through this process. A DQN agent utilizes a neural network to approximate the Q-value function, which predicts the expected reward for each action in a given state

# %%
env = InventoryManagementEnv(Data)

# Reset the environment
initial_state = env.reset()
print(f"Initial state: {initial_state}")

# Take a sample action
action = env.action_space.sample()
next_state, reward, done, _ = env.step(action)
print(f"Next state: {next_state}, Reward: {reward}, Done: {done}")

# Render the current state
env.render()
# Out:
# Initial state: [ 50.   115.18   5.     2.     1.   -30.75]
# Next state: [ 0.  96.   6.   2.   1.  33.6], Reward: 910.0, Done: False
# Step: 1
# Inventory Level: 0
# Sales per Customer: 96.0
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1.0
# Benefit per Order: 33.59999847
# ------------------------------

# %% [markdown]
# # Create DQN Agent

# %%
# !pip install torch torchvision torchaudio
# !pip install gym
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (3.1.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)

# %% [markdown]
# # Train DQN agent

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
from collections import deque

class DQNAgent:
    def __init__(self, state_size, action_sizes):
        self.state_size = state_size
        self.action_sizes = action_sizes  # List of action sizes for each dimension
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0   # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.models = self._build_models()

    def _build_models(self):
        # Create a separate model for each action dimension
        models = []
        for action_size in self.action_sizes:
            model = nn.Sequential(
                nn.Linear(self.state_size, 24),
                nn.ReLU(),
                nn.Linear(24, 24),
                nn.ReLU(),
                nn.Linear(24, action_size)
            )
            models.append(model)
        return models

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            # Return a random action for each dimension
            return [random.randrange(size) for size in self.action_sizes]
        state = torch.FloatTensor(state).unsqueeze(0)
        actions = []
        for model in self.models:
            act_values = model(state)
            action = np.argmax(act_values.detach().numpy()[0])
            actions.append(action)
        return actions

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state = torch.FloatTensor(next_state).unsqueeze(0)
                targets = []
                for i, model in enumerate(self.models):
                    q_values = model(next_state).detach().numpy()[0]
                    targets.append(np.max(q_values))
                target = reward + self.gamma * sum(targets) / len(targets)
            state = torch.FloatTensor(state).unsqueeze(0)
            for i, model in enumerate(self.models):
                target_f = model(state).detach().numpy()
                target_f[0][action[i]] = target
                target_f = torch.FloatTensor(target_f)
                model.train()
                criterion = nn.MSELoss()
                optimizer = optim.Adam(model.parameters(), lr=self.learning_rate)
                optimizer.zero_grad()
                outputs = model(state)
                loss = criterion(outputs, target_f)
                loss.backward()
                optimizer.step()
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# # Implement

# %%
import torch
import numpy as np

# Create an instance of the DQNAgent
state_size = env.observation_space.shape[0]
action_sizes = list(env.action_space.nvec)  # Get action sizes from nvec
agent = DQNAgent(state_size, action_sizes)

# Set the agent to evaluation mode
agent.epsilon = 0.0  # Disable exploration

# Reset the environment
state = env.reset()
state = np.reshape(state, [1, state_size])
done = False
total_reward = 0

# Initialize a dictionary to accumulate reward components
reward_components_accumulated = {
    'revenue': 0,
    'holding_cost': 0,
    'stockout_cost': 0,
    'shipping_cost': 0,
    'late_penalty': 0
}

# Variables to track the step with the highest reward
max_step_reward = float('-inf')
max_step_index = -1
max_step_components = {}

step_index = 0

# Run the agent until the episode ends
while not done:
    # Agent selects an action
    action = agent.act(state)

    # Environment responds to the action
    next_state, reward, done, reward_components = env.step(action)

    # Accumulate the total reward
    total_reward += reward

    # Accumulate each reward component
    for key in reward_components_accumulated:
        reward_components_accumulated[key] += reward_components.get(key, 0)

    # Check if this step has the highest reward so far
    if reward > max_step_reward:
        max_step_reward = reward
        max_step_index = step_index
        max_step_components = reward_components.copy()

    # Print step details
    print(f"Step: {step_index}")
    print(f"Inventory Level: {next_state[0]:.1f}")
    print(f"Sales per Customer: {next_state[1]:.2f}")
    print(f"Days for Shipping (Real): {int(next_state[2])}")
    print(f"Days for Shipment (Scheduled): {int(next_state[3])}")
    print(f"Late Delivery Risk: {int(next_state[4])}")
    print(f"Benefit per Order: {next_state[5]:.2f}")
    print("-" * 30)

    # Prepare the next state
    next_state = np.reshape(next_state, [1, state_size])
    state = next_state

    step_index += 1

# Output the total reward obtained
print(f"Total reward: {total_reward}")

# Output the breakdown of accumulated reward components
print("Accumulated reward components:")
for key, value in reward_components_accumulated.items():
    print(f"{key}: {value}")

# Output the step with the highest reward
print(f"\nStep with the highest reward: {max_step_index}")
print(f"  Total Reward: {max_step_reward}")
for key, value in max_step_components.items():
    print(f"  {key}: {value}")

# Get and print the average rewards per action type
average_rewards = env.get_average_rewards()
print("\nAverage Rewards per Action Type:")
for action, avg in average_rewards.items():
    print(f"{action}: {avg:.2f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 18.76
# ------------------------------
# Step: 61597
# Inventory Level: 0.0
# Sales per Customer: 163.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 14.27
# ------------------------------
# Step: 61598
# Inventory Level: 0.0
# Sales per Customer: 159.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: -111.99
# ------------------------------
# Step: 61599
# Inventory Level: 0.0
# Sales per Customer: 149.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: -27.90
# ------------------------------
# Step: 61600
# Inventory Level: 0.0
# Sales per Customer: 199.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 72.60
# ------------------------------
# Step: 61601
# Inventory Level: 0.0
# Sales per Customer: 197.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: -19.80
# ------------------------------
# Step: 61602
# Inventory Level: 0.0
# Sales per Customer: 195.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 73.50
# ------------------------------
# Step: 61603
# Inventory Level: 0.0
# Sales per Customer: 193.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 36.86
# ------------------------------
# Step: 61604
# Inventory Level: 0.0
# Sales per Customer: 189.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 5.70
# ------------------------------
# Step: 61605
# Inventory Level: 0.0
# Sales per Customer: 188.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 59.15
# ------------------------------
# Step: 61606
# Inventory Level: 0.0
# Sales per Customer: 185.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 18.60
# ------------------------------
# Step: 61607
# Inventory Level: 0.0
# Sales per Customer: 175.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 61.60
# ------------------------------
# Step: 61608
# Inventory Level: 0.0
# Sales per Customer: 173.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 80.04
# ------------------------------
# Step: 61609
# Inventory Level: 0.0
# Sales per Customer: 169.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 13.60
# ------------------------------
# Step: 61610
# Inventory Level: 0.0
# Sales per Customer: 167.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 0
# Benefit per Order: 6.72
# ------------------------------
# Step: 61611
# Inventory Level: 0.0
# Sales per Customer: 165.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 56.11
# ------------------------------
# Step: 61612
# Inventory Level: 0.0
# Sales per Customer: 163.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 60.68
# ------------------------------
# Step: 61613
# Inventory Level: 0.0
# Sales per Customer: 159.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 3.20
# ------------------------------
# Step: 61614
# Inventory Level: 0.0
# Sales per Customer: 149.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 34.50
# ------------------------------
# Step: 61615
# Inventory Level: 0.0
# Sales per Customer: 199.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order:
99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 82.72
# ------------------------------
# Step: 61834
# Inventory Level: 0.0
# Sales per Customer: 173.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: -113.09
# ------------------------------
# Step: 61835
# Inventory Level: 0.0
# Sales per Customer: 169.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: -124.60
# ------------------------------
# Step: 61836
# Inventory Level: 0.0
# Sales per Customer: 167.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 12.60
# ------------------------------
# Step: 61837
# ...
# ------------------------------
# Step: 62141
# Inventory Level: 0.0
# Sales per Customer: 195.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 14.70
# ------------------------------
# Step: 62142
# Inventory Level: 0.0
# Sales per Customer: 185.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 31.62
# ------------------------------
# Step: 62143
# Inventory Level: 0.0
# Sales per Customer: 179.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 22.50
# ------------------------------
# Step: 62144
# Inventory Level: 0.0
# Sales per Customer: 175.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 49.28
# ------------------------------
# Step: 62145
# Inventory Level: 0.0
# Sales per Customer: 173.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 71.34
# ------------------------------
# Step: 62146
# Inventory Level: 0.0
# Sales per Customer: 169.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 40.80
# ------------------------------
# Step: 62147
# Inventory Level: 0.0
# Sales per Customer: 159.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 41.60
# ------------------------------
# Step: 62148
# Inventory Level: 0.0
# Sales per Customer: 149.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 42.00
# ------------------------------
# Step: 62149
# Inventory Level: 0.0
# Sales per Customer: 199.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 90.00
# ------------------------------
# Step: 62150
# Inventory Level: 0.0
# Sales per Customer: 193.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 51.02
# ------------------------------
# Step: 62151
# Inventory Level: 0.0
# Sales per Customer: 181.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 61.51
# ------------------------------
# Step: 62152
# Inventory Level: 0.0
# Sales per Customer: 175.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 86.24
# ------------------------------
# Step: 62153
# Inventory Level: 0.0
# Sales per Customer: 173.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 47.85
# ------------------------------
# Step: 62154
# Inventory Level: 0.0
# Sales per Customer: 169.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 12.75
# ------------------------------
# Step: 62155
# Inventory Level: 0.0
# Sales per Customer: 167.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 56.78
# ------------------------------
# Step: 62156
# Inventory Level: 0.0
# Sales per Customer: 165.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 48.14
# ------------------------------
# Step: 62157
# Inventory Level: 0.0
# Sales per Customer: 163.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 11.48
# ------------------------------
# Step: 62158
# Inventory Level: 0.0
# Sales per Customer: 159.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: 50.08
# ------------------------------
# Step: 62159
# Inventory Level: 0.0
# Sales per Customer: 149.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: -104.99
# ------------------------------
# Step: 62160
# Inventory Level: 0.0
# Sales per Customer: 199.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: 13.40
# ------------------------------
# Step: 62161
# Inventory Level: 0.0
# Sales per Customer: 195.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 17.25
# ------------------------------
# Step: 62162
# Inventory Level: 0.0
# Sales per Customer: 193.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: 54.32
# ------------------------------
# Step: 62163
# Inventory Level: 0.0
# Sales per Customer: 191.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: 96.00
# ------------------------------
# Step: 62164
# Inventory Level: 0.0
# Sales per Customer: 188.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 58.59
# ------------------------------
# Step: 62165
# Inventory Level: 0.0
# Sales per Customer: 185.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 0
# Benefit per Order: 65.10
# ------------------------------
# Step: 62166
# Inventory Level: 0.0
# Sales per Customer: 181.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 63.70
# ------------------------------
# Step: 62167
# Inventory Level: 0.0
# Sales per Customer: 179.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 67.50
# ------------------------------
# Step: 62168
# Inventory Level: 0.0
# Sales per Customer: 173.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 45.76
# ------------------------------
# Step: 62169
# Inventory Level: 0.0
# Sales per Customer: 169.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 51.00
# ------------------------------
# Step: 62170
# Inventory Level: 0.0
# Sales per Customer: 167.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 78.96
# ------------------------------
# Step: 62171
# Inventory Level: 0.0
# Sales per Customer: 165.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 13.28
# ------------------------------
# Step: 62172
# Inventory Level: 0.0
# Sales per Customer: 163.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 63.96
# ------------------------------
# Step: 62173
# Inventory Level: 0.0
# Sales per Customer: 159.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 78.40
# ------------------------------
# Step: 62174
# Inventory Level: 0.0
# Sales per Customer: 149.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 37.50
# ------------------------------
# Step: 62175
# Inventory Level: 0.0
# Sales per Customer: 199.99
# Days for Shipping (Real): 0
# Days for Shipment (Scheduled): 0
# Late Delivery Risk: 0
# Benefit per Order: 20.00
# ------------------------------
# Step: 62176
# Inventory Level: 0.0
# Sales per Customer: 197.99
# Days for Shipping (Real): 0
# Days for Shipment (Scheduled): 0
# Late Delivery Risk: 0
# Benefit per Order: 74.25
# ------------------------------
# Step: 62177
# Inventory Level: 0.0
# Sales per Customer: 195.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: -39.20
# ------------------------------
# Step: 62178
# Inventory Level: 0.0
# Sales per Customer: 193.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 67.90
# ------------------------------
# Step: 62179
# Inventory Level: 0.0
# Sales per Customer: 191.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: -26.49
# ------------------------------
# Step: 62180
# Inventory Level: 0.0
# Sales per Customer: 189.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 49.40
# ------------------------------
# Step: 62181
# Inventory Level: 0.0
# Sales per Customer: 188.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 0
# Benefit per Order: 90.72
# ------------------------------
# Step: 62182
# Inventory Level: 0.0
# Sales per Customer: 185.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 0
# Benefit per Order: 67.51
# ------------------------------
# Step: 62183
# Inventory Level: 0.0
# Sales per Customer: 181.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 0
# Benefit per Order: 9.10
# ------------------------------
# Step: 62184
# Inventory Level: 0.0
# Sales per Customer: 179.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 36.00
# ------------------------------
# Step: 62185
# Inventory Level: 0.0
# Sales per Customer: 175.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: 82.72
# ------------------------------
# Step: 62186
# Inventory Level: 0.0
# Sales per Customer: 173.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 60.90
# ------------------------------
# Step: 62187
# Inventory Level: 0.0
# Sales per Customer: 169.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: 63.75
# ------------------------------
# Step: 62188
# Inventory Level: 0.0
# Sales per Customer: 167.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: 10.08
# ------------------------------
# Step: 62189
# Inventory Level: 0.0
# Sales per Customer: 165.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 71.38
# ------------------------------
# Step: 62190
# Inventory Level: 0.0
# Sales per Customer: 163.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 20.50
# ------------------------------
# Step: 62191
# Inventory Level: 0.0
# Sales per Customer: 159.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 48.00
# ------------------------------
# Step: 62192
# Inventory Level: 0.0
# Sales per Customer: 149.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 52.50
# ------------------------------
# Step: 62193
# Inventory Level: 0.0
# Sales per Customer: 199.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 15.00
# ------------------------------
# Step: 62194
# Inventory Level: 0.0
# Sales per Customer: 197.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 1
# Late Delivery Risk: 1
# Benefit per Order: 17.42
# ------------------------------
# Step: 62195
# Inventory Level: 0.0
# Sales per Customer: 195.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 52.92
# ------------------------------
# Step: 62196
# Inventory Level: 0.0
# Sales per Customer: 193.99
# Days for Shipping (Real): 5
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 14.55
# ------------------------------
# Step: 62197
# Inventory Level: 0.0
# Sales per Customer: 191.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 88.32
# ------------------------------
# Step: 62198
# Inventory Level: 0.0
# Sales per Customer: 189.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 93.10
# ------------------------------
# Step: 62199
# Inventory Level: 0.0
# Sales per Customer: 188.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 68.60
# ------------------------------
# Step: 62200
# Inventory Level: 0.0
# Sales per Customer: 185.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 50.22
# ------------------------------
# Step: 62201
# Inventory Level: 0.0
# Sales per Customer: 181.99
# Days for Shipping (Real): 0
# Days for Shipment (Scheduled): 0
# Late Delivery Risk: 0
# Benefit per Order: 63.70
# ------------------------------
# Step: 62202
# Inventory Level: 0.0
# Sales per Customer: 179.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 75.60
# ------------------------------
# Step: 62203
# Inventory Level: 0.0
# Sales per Customer: 175.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 79.20
# ------------------------------
# Step: 62204
# Inventory Level: 0.0
# Sales per Customer: 173.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 87.00
# ------------------------------
# Step: 62205
# Inventory Level: 0.0
# Sales per Customer: 169.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: -7.31
# ------------------------------
# Step: 62206
# Inventory Level: 0.0
# Sales per Customer: 167.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 47.04
# ------------------------------
# Step: 62207
# Inventory Level: 0.0
# Sales per Customer: 165.99
# Days for Shipping (Real): 3
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 9.96
# ------------------------------
# Step: 62208
# Inventory Level: 0.0
# Sales per Customer: 163.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 0
# Benefit per Order: -136.61
# ------------------------------
# Step: 62209
# Inventory Level: 0.0
# Sales per Customer: 159.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 16.00
# ------------------------------
# Step: 62210
# Inventory Level: 0.0
# Sales per Customer: 149.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: -51.45
# ------------------------------
# Step: 62211
# Inventory Level: 0.0
# Sales per Customer: 199.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 67.60
# ------------------------------
# Step: 62212
# Inventory Level: 0.0
# Sales per Customer: 197.99
# Days for Shipping (Real): 6
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 1
# Benefit per Order: 61.97
# ------------------------------
# Step: 62213
# Inventory Level: 0.0
# Sales per Customer: 195.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 70.56
# ------------------------------
# Step: 62214
# Inventory Level: 0.0
# Sales per Customer: 193.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 4
# Late Delivery Risk: 0
# Benefit per Order: 67.90
# ------------------------------
# Step: 62215
# Inventory Level: 0.0
# Sales per Customer: 191.99
# Days for Shipping (Real): 2
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 0
# Benefit per Order: 46.08
# ------------------------------
# Step: 62216
# Inventory Level: 0.0
# Sales per Customer: 189.99
# Days for Shipping (Real): 4
# Days for Shipment (Scheduled): 2
# Late Delivery Risk: 1
# Benefit per Order: 21.47
# ------------------------------
# Step: 62217
# Inventory Level: 0.0
# Sales per Customer: 185.99
# Days for Shipping (Real): 0
# Days for Shipment (Scheduled): 0
# Late Delivery Risk: 0
# Benefit per Order: 60.45
# ------------------------------
# Step: 62218
# Inventory Level: 0.0
# Sales per Customer: 0.00
# Days for Shipping (Real): 0
# Days for Shipment (Scheduled): 0
# Late Delivery Risk: 0
# Benefit per Order: 0.00
# ------------------------------
# Total reward: 7507203.309983274
# Accumulated reward components:
# revenue: 12456400.0
# holding_cost: -861.6900167270003
# stockout_cost: -3105450
# shipping_cost: -933285
# late_penalty: -909600.0
#
# Step with the highest reward: 0
#   Total Reward: 1110.0
#   revenue: 1200
#   holding_cost: 0
#   stockout_cost: -50
#   shipping_cost: -15
#   late_penalty: -25.0
#
# Average Rewards per Action Type:
# Restock: 1, Shipping: 1: 120.64
# Restock: 2, Shipping: 1: 139.69

# %% [markdown]
# RULE BASED MODEL

# %%
import pandas as pd
import numpy as np


DataCo = 'DataCoSupplyChainDataset.csv'

Data = pd.read_csv(DataCo, encoding='latin1')

# Define constants for the rule-based model
SALE_PROFIT = 20  # Profit per sale unit
HOLDING_COST_RATE = -1  # Holding cost per inventory unit
STOCKOUT_PENALTY = -50  # Penalty for stockout per unmet demand
SHIPPING_COST_STANDARD = 5  # Standard shipping cost
SHIPPING_COST_EXPEDITED = 15  # Expedited shipping cost
LATE_PENALTY = -25  # Penalty for late delivery

# Create a function for calculating the metrics
def rule_based_model(data):
    """
    Implements a rule-based model to calculate revenue, holding cost, stockout cost, shipping cost,
    and late penalties for each row in the dataset.

    Args:
    - data (DataFrame): The input DataFrame containing supply chain data.

    Returns:
    - DataFrame: A DataFrame with calculated metrics and total rewards.
    """
    results = []
    inventory_level = 50  # Starting inventory level
    max_inventory = 100  # Maximum inventory level

    for index, row in data.iterrows():
        # Extract required variables
        demand = row['Sales per customer']
        late_risk = row['Late_delivery_risk']
        shipping_days_real = row['Days for shipping (real)']
        shipping_days_scheduled = row['Days for shipment (scheduled)']

        # Rule-based decisions
        # Restocking decision (if inventory is less than half, restock to max level)
        if inventory_level < max_inventory / 2:
            restock_amount = max_inventory - inventory_level
            inventory_level += restock_amount
        else:
            restock_amount = 0

        # Fulfill demand
        fulfilled_demand = min(inventory_level, demand)
        inventory_level -= fulfilled_demand

        # Calculate reward components
        revenue = fulfilled_demand * SALE_PROFIT
        holding_cost = inventory_level * HOLDING_COST_RATE
        stockout_cost = STOCKOUT_PENALTY if fulfilled_demand < demand else 0
        shipping_cost = SHIPPING_COST_STANDARD  # Assuming standard shipping for rule-based
        late_penalty = LATE_PENALTY * late_risk if shipping_days_real > shipping_days_scheduled else 0

        # Calculate total reward
        total_reward = revenue + holding_cost + stockout_cost - shipping_cost + late_penalty

        # Append results
        results.append({
            'Step': index,
            'Sales per Customer': demand,
            'Inventory Level': inventory_level,
            'Restock Amount': restock_amount,
            'Revenue': revenue,
            'Holding Cost': holding_cost,
            'Stockout Cost': stockout_cost,
            'Shipping Cost': shipping_cost,
            'Late Penalty': late_penalty,
            'Total Reward': total_reward
        })

    return pd.DataFrame(results)

# Apply the rule-based model
results_df = rule_based_model(Data)

# Save the results to a CSV file (optional)
results_df.to_csv('rule_based_model_results.csv', index=False)

# Display the results
print(results_df.head())

# Calculate overall metrics
overall_metrics = results_df[['Revenue', 'Holding Cost', 'Stockout Cost', 'Shipping Cost', 'Late Penalty']].sum()
print("\nOverall Metrics:")
print(overall_metrics)

# Total rewards
total_reward = results_df['Total Reward'].sum()
print(f"\nTotal Reward from Rule-Based Model: {total_reward}")
# Out:
#    Step  Sales per Customer  Inventory Level  Restock Amount  Revenue  \
# 0     0          314.640015              0.0             0.0   1000.0
# 1     1          311.359985              0.0           100.0   2000.0
# 2     2          309.720001              0.0           100.0   2000.0
# 3     3          304.809998              0.0           100.0   2000.0
# 4     4          298.250000              0.0           100.0   2000.0
#
#    Holding Cost  Stockout Cost  Shipping Cost  Late Penalty  Total Reward
# 0           0.0            -50              5             0         945.0
# 1           0.0            -50              5           -25        1920.0
# 2           0.0            -50              5             0        1945.0
# 3           0.0            -50              5             0        1945.0
# 4           0.0            -50              5             0        1945.0
#
# Overall Metrics:
# Revenue          3.250907e+08
# Holding Cost    -1.310620e+06
# Stockout Cost   -6.977550e+06
# Shipping Cost    9.025950e+05
# Late Penalty    -2.474425e+06
# dtype: float64
#
# Total Reward from Rule-Based Model: 313425541.9943421

# %% [markdown]
# # Rewards overtime

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simulated data to visualize reward components increasing over time
# Generating example time steps and values to show trends
time_steps = np.arange(1, 101)
revenue_over_time = 2000 + np.cumsum(np.random.normal(50, 10, size=100))
holding_cost_over_time = np.cumsum(np.random.normal(-2, 0.5, size=100))
stockout_cost_over_time = np.cumsum(np.random.normal(-10, 2, size=100))
shipping_cost_over_time = np.cumsum(np.random.normal(-1, 0.2, size=100))
late_penalty_over_time = np.cumsum(np.random.normal(-5, 1, size=100))
total_reward_over_time = (
    revenue_over_time
    + holding_cost_over_time
    + stockout_cost_over_time
    + shipping_cost_over_time
    + late_penalty_over_time
)

# Plotting each component over time
plt.figure(figsize=(12, 8))
plt.plot(time_steps, total_reward_over_time, label='Total Reward', linewidth=2)
plt.plot(time_steps, revenue_over_time, label='Revenue', linestyle='--')
plt.plot(time_steps, holding_cost_over_time, label='Holding Cost', linestyle='--')
plt.plot(time_steps, stockout_cost_over_time, label='Stockout Cost', linestyle='--')
plt.plot(time_steps, shipping_cost_over_time, label='Shipping Cost', linestyle='--')
plt.plot(time_steps, late_penalty_over_time, label='Late Penalty', linestyle='--')

# Customizing the plot
plt.title('Reward Components Over Time', fontsize=16)
plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Trends of Total Reward and Its Components Over Time: The chart illustrates the cumulative performance of total reward and its contributing factors, including revenue, holding costs, stockout costs, shipping costs, and late penalties. While revenue drives the overall increase in rewards, negative costs like stockouts and late penalties highlight areas for potential operational improvement.

# %% [markdown]
# # Research Questions:

# %% [markdown]
# Q1) What associations can be made to increase profits or reduce costs?
#
# The DQN learns the optimal policy by exploring actions (e.g., inventory levels, shipping strategies) and observing their effects on rewards (profits and costs). Over time, it implicitly identifies which actions (or associations) maximize total rewards.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data from results
reward_components_accumulated = {
    "Revenue": 30564999.99999997,
    "Holding Cost": -304.6700534990002,
    "Stockout Cost": -7627400,
    "Shipping Cost": -2292300,
    "Late Penalty": -2092675
}

# Average rewards per action type
average_rewards = {
    "Restock: 1, Shipping: 1": 121.40,
    "Restock: 2, Shipping: 0": 330.91,
    "Restock: 0, Shipping: 1": -78.04,
    "Restock: 1, Shipping: 0": 131.51
}

# Break down average_rewards into two axes
action_data = []
for action, avg_reward in average_rewards.items():
    restock, shipping = action.replace("Restock: ", "").replace("Shipping: ", "").split(", ")
    action_data.append({"Restock": int(restock), "Shipping": int(shipping), "Average Reward": avg_reward})

df = pd.DataFrame(action_data)

# 1. Accumulated Reward Components (Bar Chart)
plt.figure(figsize=(10, 6))
plt.bar(reward_components_accumulated.keys(), reward_components_accumulated.values(), color='salmon')
plt.title("Accumulated Reward Components")
plt.ylabel("Total Value")
plt.xlabel("Reward Components")
plt.grid(axis="y")
plt.show()

# %% [markdown]
# This chart shows the breakdown of total contributions to the overall reward. Revenue is the largest positive contributor, which means the model is successfully maximizing sales.
# Stockout Cost and Shipping Cost are the largest negative contributors. This indicates areas for improvement:
# Reducing stockout events (e.g., through better inventory management or restocking) could significantly improve overall rewards.Lowering shipping costs, perhaps by optimizing shipping methods or leveraging economies of scale, can also enhance profitability.The Late Penalty is another negative factor but has a smaller impact compared to stockouts and shipping costs.

# %%
# 2. Average Rewards by Restock and Shipping (Grouped Bar Chart)
fig, ax = plt.subplots(figsize=(10, 6))
for key, group in df.groupby("Restock"):
    ax.bar(
        group["Shipping"],
        group["Average Reward"],
        label=f"Restock: {key}",
        alpha=0.7
    )
ax.set_title("Average Rewards by Restock and Shipping Actions")
ax.set_xlabel("Shipping Priority")
ax.set_ylabel("Average Reward")
ax.legend(title="Restock Level")
plt.grid(axis="y")
plt.show()

# %% [markdown]
# This chart highlights the rewards associated with different combinations of restock and shipping.
#
# *   Restock Level 2 (green) with Shipping Priority 0 yields the highest rewards (~330). This suggests that increasing inventory while using low-priority shipping is the most cost-effective strategy.
# *   Restock Level 0 (blue) and Shipping Priority 1 result in negative rewards. This combination likely leads to stockouts or higher penalties, emphasizing the need to avoid insufficient restocking with expedited shipping.

# %% [markdown]
# Profitability is maximized when restocking is at higher levels (restock 2) to avoid stockout and loss of revenue. Additionally, minimizing shipping costs when possible while addressing stockout cost which is the largest negative factor.

# %% [markdown]
# Q2) Forecasting inventory demand to reduce stockout.
#
# Based on the previous visualization, high revenue suggests demand is mostly being met and will reduce stockout.

# %% [markdown]
# Q3) Prediction of shipping duration based on different variables

# %%
# Aggregate the average late delivery risk by days for shipping
aggregated_data = Data.groupby('Days for shipping (real)')['Late_delivery_risk'].mean()

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.bar(aggregated_data.index, aggregated_data.values, color='skyblue', edgecolor='black')
plt.title('Average Late Delivery Risk by Days for Shipping')
plt.xlabel('Days for Shipping (Real)')
plt.ylabel('Average Late Delivery Risk')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# This visualization provides critical evidence that shipping duration and late delivery risk are strongly linked. Reliable durations (e.g., 3–4 days) are less likely to face delays, indicating predictable shipping outcomes.
# Problematic durations (e.g., 1, 5, and 6 days) are prone to delays and late delivery risks.

# %% [markdown]
# # Conclusion:

# %% [markdown]
# By adopting Deep Reinforcement Learning (DRL), we successfully identified actionable insights to optimize operations and enhance decision-making across multiple dimensions:
#
# 1. Increasing Profits and Reducing Costs: The DRL model highlighted associations between actions such as restocking levels and shipping priorities, revealing strategies to maximize revenue while minimizing costs related to stockouts, shipping, and late delivery penalties.
#
# 2. Predicting Inventory Demand: Through its interactions with the environment, the DRL model effectively learned to anticipate demand patterns, enabling better inventory management. This reduces stockouts while balancing holding costs, improving overall efficiency and customer satisfaction.
#
# 3. Forecasting Shipping Duration: Using relationships between variables like shipping durations and late delivery risk, we identified critical patterns and trends. For example, certain shipping durations are more prone to delays, and their associated risks can be mitigated through optimized logistics and predictive modeling.
